# %% [markdown]
# Em Agosto de 2023 a NIST publicou um draft da norma FIPS203  para um Key Encapsulation Mechanism (KEM) derivado dos algoritmos KYBER.
# O preâmbulo do “draft”:
#
# *A key-encapsulation mechanism (or KEM) is a set of algorithms that, under certain conditions, can be used by two parties to establish a shared secret key over a public channel. A shared secret key that is securely established using a KEM can then be used with symmetric-key cryptographic algorithms to perform basic tasks in secure communications, such as encryption and authentication. This standard specifes a key-encapsulation mechanism called ML-KEM. The security of ML-KEM is related to the computational diffculty of the so-called Module Learning with Errorsproblem. At present, ML-KEM is believed to be secure even against adversaries who possess a quantum computer*
#
#
# Neste trabalho pretende-se implementar em Sagemath um protótipo deste standard parametrizado de acordo com as variantes sugeridas na norma (512, 768 e 1024 bits de segurança).

# %% [markdown]
# ML-KEM é um mecanismo de encapsulamento de chaves recentemente padronizado baseado em retículos.
#
# Este utiliza o Módulo de Aprendizado com Erros como primitiva subjacente, que é uma variante estruturada de retículos que oferece bom desempenho e tamanhos de chave e texto cifrado relativamente pequenos e equilibrados. ML-KEM foi padronizado com três parâmetros: ML-KEM-512, ML-KEM-768 e ML-KEM-1024. Estes foram mapeados pelo NIST para os três níveis de segurança definidos no Projeto PQC do NIST: nível 1, 3 e 5. Esses níveis correspondem à dificuldade de quebrar AES-128, AES-192 e AES-256, respetivamente.
#
# Esta especificação introduz o ML-KEM-768 e ML-KEM-1024 nas trocas de chaves do IKEv2 como parâmetros de nível de segurança conservadores que não terão impacto significativo no desempenho dos túneis IKEv2/IPsec, que geralmente permanecem ativos por longos períodos de tempo. Como os tamanhos de chave pública e texto cifrado do ML-KEM-768 e ML-KEM-1024 podem exceder o MTU típico da rede, essas trocas de chaves geralmente exigem dois ou três pacotes IP de rede tanto de quem inicia quanto do que responde.
# (https://www.ietf.org/archive/id/draft-kampanakis-ml-kem-ikev2-01.html)
# (https://nvlpubs.nist.gov/nistpubs/FIPS/NIST.FIPS.203.ipd.pdf)

# %%
from typing import List, Tuple
import hashlib
import os
from functools import reduce
from shakestream import ShakeStream
#import sage.all

# %% [markdown]
# O FIPS-203 especifica o ML-KEM, que foi baseado no único vencedor do KEM da Competição Pós-Quântica do NIST: Kyber. O ML-KEM define 3 conjuntos de parâmetros, cada um em um nível diferente de segurança:
#
# 1. ML-KEM-512 (equivalência de segurança ao AES-128, nível 1 de quebra)
# 2. ML-KEM-768 (equivalência de segurança ao AES-192, nível 3 de quebra)
# 3. ML-KEM-1024 (equivalência de segurança ao AES-256, nível 5 de quebra)
#
# O ML-KEM é apropriado como uma substituição geral para algoritmos de troca de chaves vulneráveis ​​a ataques quânticos, como ECDH ou FFDH. É notável que ECDH e FFDH são algoritmos de Troca de Chave Não-Interativa (NIKE), mas ML-KEM não é, então, para aplicações onde a não-interatividade é um requisito, ML-KEM NÃO é uma substituição apropriada. Embora o desempenho do ML-KEM seja muito bom, os tamanhos dos artefatos criptográficos são maiores do que os do ECDH e do FFDH.

# %%
# ML-KEM-768 params:
N = 256
Q = 3329
K = 3
ETA1 = 2
ETA2 = 2
DU = 10
DV = 4

# # ML-KEM-512 params:
# N_512 = 256
# Q_512 = 3329
# K_512 = 2
# ETA1_512 = 3
# ETA2_512 = 2
# DU_512 = 10
# DV_512 = 4

# # ML-KEM-768 params:
# N_768 = 256
# Q_768 = 3329
# K_768 = 3
# ETA1_768 = 2
# ETA2_768 = 2
# DU_768 = 10
# DV_768 = 4

# # ML-KEM-1024 params:
# N_1024 = 256
# Q_1024 = 3329
# K_1024 = 4
# ETA1_1024 = 2
# ETA2_1024 = 2
# DU_1024 = 11
# DV_1024 = 5

# %%
# Definindo o anel Zq
q = 3329  # Este é um primo para o qual 17 é primitivo
Zq = IntegerModRing(q)

def bitrev7(n: int) -> int:
    return int(f"{n:07b}"[::-1], 2)

ZETA = [pow(17, bitrev7(k), Q) for k in range(128)] # used in ntt and ntt_inv
GAMMA = [pow(17, 2*bitrev7(k)+1, Q) for k in range(128)] # used in ntt_mul

    for i in range(256):
        for j in range(256):
            c[i+j] = (c[i+j] + a[j] * b[i]) % q

    # Redução mod X^256 + 1
    for i in range(255):
        c[i] = (c[i] - c[i+256]) % q
    
    # Truncar c
    return c[:256]

# O(n^2) multiplication algorithm for testing/comparison purposes
def poly256_slow_mul(a: List[int], b: List[int]) -> List[int]:
	c = [0] * 511

	for i in range(256):
		for j in range(256):
			c[i+j] = (c[i+j] + a[j] * b[i]) % Q

	# reduction mod X^256 + 1
	for i in range(255):
		c[i] = (c[i] - c[i+256]) % Q
	
	# truncate c
	return c[:256]

    return f_out

# O(n logn)
def ntt(f_in: List[int]) -> List[int]:
	f_out = f_in.copy()
	k = 1
	for log2len in range(7, 0, -1):
		length = 2**log2len
		for start in range(0, 256, 2 * length):
			zeta = ZETA[k]
			k += 1
			for j in range(start, start + length):
				t = (zeta * f_out[j + length]) % Q
				f_out[j + length] = (f_out[j] - t) % Q
				f_out[j] = (f_out[j] + t) % Q
	return f_out


# O(n logn)
def ntt_inv(f_in: List[int]) -> List[int]:
	f_out = f_in.copy()
	k = 127
	for log2len in range(1, 8):
		length = 2**log2len
		for start in range(0, 256, 2 * length):
			zeta = ZETA[k]
			k -= 1
			for j in range(start, start + length):
				t = f_out[j]
				f_out[j] = (t + f_out[j + length]) % Q
				f_out[j + length] = (zeta * (f_out[j + length] - t)) % Q

	for i in range(256):
		f_out[i] = (f_out[i] * 3303) % Q  # 3303 == pow(128, -1, Q)

	return f_out

ntt_add = poly256_add  # it's just elementwise addition

#  O(n)
def ntt_mul(a: List[int], b: List[int]) -> List[int]:
    c = []
    # guarantees that the list has a sufficient size
    a += [0] * (256 - len(a))
    for i in range(128):
        a0, a1 = a[2 * i: 2 * i + 2]
        b0, b1 = b[2 * i: 2 * i + 2]
        c.append((a0 * b0 + a1 * b1 * GAMMA[i]) % q)
        c.append((a0 * b1 + a1 * b0) % q)
    return c

# crypto functions

def mlkem_prf(eta: int, data: bytes, b: int) -> bytes:
	return hashlib.shake_256(data + bytes([b])).digest(64 * eta)

def mlkem_xof(data: bytes, i: int, j: int) -> ShakeStream:
	return ShakeStream(hashlib.shake_128(data + bytes([i, j])).digest)

def mlkem_hash_H(data: bytes) -> bytes:
    # Você pode usar a função de hash SHA3_256 do SageMath
    h = hashlib.sha3_256(data).digest()
    return bytes_to_list(h)

def mlkem_hash_J(data: bytes) -> bytes:
    # Você pode usar a função de hash SHAKE256 do SageMath
    h = hashlib.shake_256(data).digest(32)
    return bytes_to_list(h)

def mlkem_hash_G(data: bytes) -> bytes:
    # Você pode usar a função de hash SHA3_512 do SageMath
    h = hashlib.sha3_512(data).digest()
    return bytes_to_list(h)

# %%
# encode/decode logic

def bits_to_bytes(bits: List[int]) -> bytes:
	assert(len(bits) % 8 == 0)
	return bytes(
		sum(bits[i + j] << j for j in range(8))
		for i in range(0, len(bits), 8)
	)

def bytes_to_bits(data: bytes) -> List[int]:
	bits = []
	for word in data:
		for i in range(8):
			bits.append((word >> i) & 1)
	return bits

def byte_encode(d: int, f: List[int]) -> bytes:
	assert(len(f) == 256)
	bits = []
	for a in f:
		for i in range(d):
			bits.append((a >> i) & 1)
	return bits_to_bytes(bits)

def byte_decode(d: int, data: bytes) -> List[int]:
    bits = bytes_to_bits(data)
    num_elements = len(bits) // d
    return [sum(bits[i * d + j] << j for j in range(d)) for i in range(num_elements)]

def compress(d: int, x: List[int]) -> List[int]:
	return [(((n * 2**d) + Q // 2 ) // Q) % (2**d) for n in x]

def decompress(d: int, x: List[int]) -> List[int]:
	return [(((n * Q) + 2**(d-1) ) // 2**d) % Q for n in x]

# %%
# sampling

def sample_ntt(xof: ShakeStream):
	res = []
	while len(res) < 256:
		a, b, c = xof.read(3)
		d1 = ((b & 0xf) << 8) | a
		d2 = c << 4 | b >> 4
		if d1 < Q:
			res.append(d1)
		if d2 < Q and len(res) < 256:
			res.append(d2)
	return res


def sample_poly_cbd(eta: int, data: bytes) -> List[int]:
	assert(len(data) == 64 * eta)
	bits = bytes_to_bits(data)
	f = []
	for i in range(256):
		x = sum(bits[2*i*eta+j] for j in range(eta))
		y = sum(bits[2*i*eta+eta+j] for j in range(eta))
		f.append((x - y) % Q)
	return f


# K-PKE

def kpke_keygen(seed: bytes=None) -> Tuple[bytes, bytes]:
	d = os.urandom(32) if seed is None else seed
	ghash = mlkem_hash_G(d)
	rho, sigma = ghash[:32], ghash[32:]

	ahat = []
	for i in range(K):
		row = []
		for j in range(K):
			row.append(sample_ntt(mlkem_xof(rho, i, j)))
		ahat.append(row)
	
	shat = [
		ntt(sample_poly_cbd(ETA1, mlkem_prf(ETA1, sigma, i)))
		for i in range(K)
	]
	ehat = [
		ntt(sample_poly_cbd(ETA1, mlkem_prf(ETA1, sigma, i+K)))
		for i in range(K)
	]
	that = [ # t = a * s + e
		reduce(ntt_add, [
			ntt_mul(ahat[j][i], shat[j])
			for j in range(K)
		] + [ehat[i]])
		for i in range(K)
	]
	print("Type rho", type(rho))
	print("Type that", type(that))
	ek_pke = b"".join(byte_encode(12, [int(a) for a in s]) for s in that) + rho
	dk_pke = b"".join(byte_encode(12, [int(a) for a in s]) for s in shat)
	return ek_pke, dk_pke


def kpke_encrypt(ek_pke: bytes, m: bytes, r: bytes) -> bytes:
    #print("Encrypting...")
    that = [byte_decode(12, ek_pke[i*128*K:(i+1)*128*K]) for i in range(K)]
    rho = ek_pke[-32:]

    # guarantees that the list has a sufficient size
    that += [[0] * 256] * (K - len(that))
    
    # Identical to as in kpke_keygen
    ahat = []
    for i in range(K):
        row = []
        for j in range(K):
            row.append(sample_ntt(mlkem_xof(rho, i, j)))
        ahat.append(row)
    
    rhat = [
        ntt(sample_poly_cbd(ETA1, mlkem_prf(ETA1, r, i)))
        for i in range(K)
    ]
    e1 = [
        sample_poly_cbd(ETA2, mlkem_prf(ETA2, r, i+K))
        for i in range(K)
    ]
    e2 = sample_poly_cbd(ETA2, mlkem_prf(ETA2, r, 2*K))

    u = [ # u = ntt-1(AT*r)+e1
        poly256_add(ntt_inv(reduce(ntt_add, [
            ntt_mul(ahat[i][j], rhat[j]) # i,j are reversed here
            for j in range(K)
        ])), e1[i])
        for i in range(K)
    ]
    mu = decompress(1, byte_decode(1, m))

    # guarantees that the list has a sufficient size
    u += [[0, 0]] * (K - len(u))
    
    v = poly256_add(ntt_inv(reduce(ntt_add, [
        ntt_mul(that[i], rhat[i])
        for i in range(K)
    ])), poly256_add(e2, mu))

    c1 = b"".join(byte_encode(DU, compress(DU, u[i])) for i in range(K))
    c2 = byte_encode(DV, compress(DV, v))
    #print("Encryption complete.")
    return c1 + c2


def kpke_decrypt(dk_pke: bytes, c: bytes) -> bytes:
    #print("Decrypting...")
    c1 = c[:32*DU*K]
    c2 = c[32*DU*K:]
    print("c1", c1)
    print("c2", c2)
    u = [
        decompress(DU, byte_decode(DU, c1[i*32*DU:(i+1)*32*DU]))
        for i in range(K)
    ]
    v = decompress(DV, byte_decode(DV, c2))
    shat = [byte_decode(12, dk_pke[i*384:(i+1)*384]) for i in range(K)]
    w = poly256_sub(v, ntt_inv(reduce(ntt_add, [
        ntt_mul(shat[i], ntt(u[i]))
        for i in range(K)
    ])))
    m = byte_encode(1, compress(1, w))
    #print("Decryption complete.")
    return m

# KEM

def mlkem_keygen(seed1=None, seed2=None):
	z = os.urandom(32) if seed1 is None else seed1
	ek_pke, dk_pke = kpke_keygen(seed2)
	ek = ek_pke
	dk = dk_pke + ek + mlkem_hash_H(ek) + z
	return ek, dk


def mlkem_encaps(ek: bytes, seed=None) -> Tuple[bytes, bytes]:
    m = os.urandom(32) if seed is None else seed
    #print("Mensagem m:", m.hex())
    ghash = mlkem_hash_G(m + mlkem_hash_H(ek))
    k = ghash[:32]
    r = ghash[32:]
    #print("Chave k:", k.hex())
    #print("Vetor de inicialização r:", r.hex())
    c = kpke_encrypt(ek, m, r)
    #print("Texto cifrado c:", c.hex())
    return k, c


def mlkem_decaps(c: bytes, dk: bytes) -> bytes:
    dk_pke = dk[:384*K]
    ek_pke = dk[384*K : 768*K + 32]
    h = dk[768*K + 32 : 768*K + 64]
    z = dk[768*K + 64 : 768*K + 96]
    mdash = kpke_decrypt(dk_pke, c)
    #print("Mensagem descriptografada mdash:", mdash.hex())
    ghash = mlkem_hash_G(mdash + h)
    kdash = ghash[:32]
    rdash = ghash[32:]
    kbar = mlkem_hash_J(z + c)
    cdash = kpke_encrypt(ek_pke, mdash, rdash)
    #print("Texto cifrado cdash:", cdash.hex())
    if cdash != c:
        print("Os textos cifrados não coincidem")
        return kbar
    return kdash

# %%
if __name__ == "__main__":
	a = list(range(256))
	b = list(range(1024, 1024+256))

	ntt_res = ntt_inv(ntt_add(ntt(a), ntt(b)))
	poly_res = poly256_add(a, b)
	print("ntt_res:", ntt_res)
	print("poly_res:", poly_res)

	assert(ntt_res == poly_res)

	ntt_prod = ntt_inv(ntt_mul(ntt(a), ntt(b)))
	poly_prod = poly256_slow_mul(a, b)
	print("ntt_prod:", ntt_prod)
	print("poly_prod:", poly_prod)

	assert(ntt_prod == poly_prod)

	ek_pke, dk_pke = kpke_keygen(b"SEED"*8)
	print("ek", ek_pke)
	print("dk", dk_pke)

	msg = b"This is a demonstration message."
	ct = kpke_encrypt(ek_pke, msg, b"RAND"*8)
	print("ct:", ct)
	pt = kpke_decrypt(dk_pke, ct)
	print("pt:", pt)
	#print("Type of pt:", type(pt))
	#print("Type of msg:", type(msg))
	#msg = msg.decode('utf-8') 
	print("pt (hex):", pt.hex())
	print("msg (hex):", msg.hex())

	assert(pt == msg)

	ek, dk = mlkem_keygen()
	k1, c = mlkem_encaps(ek)
	print("encapsulated:", k1.hex())

	k2 = mlkem_decaps(c, dk)
	print("decapsulated:", k2.hex())

	assert(k1 == k2)
	
# if __name__ == "__main__":
    # Teste para ML-KEM-xxx
    # print("Teste para ML-KEM-512:")
    # ek_pke, dk_pke = mlkem_keygen()
    # k1, c = mlkem_encaps(ek_pke)
    # k2 = mlkem_decaps(c, dk_pke)
    
    # assert k1 == k2
# Out:
# ntt_res: [1024, 1026, 1028, 1030, 1032, 1034, 1036, 1038, 1040, 1042, 1044, 1046, 1048, 1050, 1052, 1054, 1056, 1058, 1060, 1062, 1064, 1066, 1068, 1070, 1072, 1074, 1076, 1078, 1080, 1082, 1084, 1086, 1088, 1090, 1092, 1094, 1096, 1098, 1100, 1102, 1104, 1106, 1108, 1110, 1112, 1114, 1116, 1118, 1120, 1122, 1124, 1126, 1128, 1130, 1132, 1134, 1136, 1138, 1140, 1142, 1144, 1146, 1148, 1150, 1152, 1154, 1156, 1158, 1160, 1162, 1164, 1166, 1168, 1170, 1172, 1174, 1176, 1178, 1180, 1182, 1184, 1186, 1188, 1190, 1192, 1194, 1196, 1198, 1200, 1202, 1204, 1206, 1208, 1210, 1212, 1214, 1216, 1218, 1220, 1222, 1224, 1226, 1228, 1230, 1232, 1234, 1236, 1238, 1240, 1242, 1244, 1246, 1248, 1250, 1252, 1254, 1256, 1258, 1260, 1262, 1264, 1266, 1268, 1270, 1272, 1274, 1276, 1278, 1280, 1282, 1284, 1286, 1288, 1290, 1292, 1294, 1296, 1298, 1300, 1302, 1304, 1306, 1308, 1310, 1312, 1314, 1316, 1318, 1320, 1322, 1324, 1326, 1328, 1330, 1332, 1334, 1336, 1338, 1340, 1342, 1344, 1346, 1348, 1350, 1352, 1354, 1356, 1358, 1360, 1362, 1364, 1366, 1368, 1370, 1372, 1374, 1376, 1378, 1380, 1382, 1384, 1386, 1388, 1390, 1392, 1394, 1396, 1398, 1400, 1402, 1404, 1406, 1408, 1410, 1412, 1414, 1416, 1418, 1420, 1422, 1424, 1426, 1428, 1430, 1432, 1434, 1436, 1438, 1440, 1442, 1444, 1446, 1448, 1450, 1452, 1454, 1456, 1458, 1460, 1462, 1464, 1466, 1468, 1470, 1472, 1474, 1476, 1478, 1480, 1482, 1484, 1486, 1488, 1490, 1492, 1494, 1496, 1498, 1500, 1502, 1504, 1506, 1508, 1510, 1512, 1514, 1516, 1518, 1520, 1522, 1524, 1526, 1528, 1530, 1532, 1534]
# poly_res: [1024, 1026, 1028, 1030, 1032, 1034, 1036, 1038, 1040, 1042, 1044, 1046, 1048, 1050, 1052, 1054, 1056, 1058, 1060, 1062, 1064, 1066, 1068, 1070, 1072, 1074, 1076, 1078, 1080, 1082, 1084, 1086, 1088, 1090, 1092, 1094, 1096, 1098, 1100, 1102, 1104, 1106, 1108, 1110, 1112, 1114, 1116, 1118, 1120, 1122, 1124, 1126, 1128, 1130, 1132, 1134, 1136, 1138, 1140, 1142, 1144, 1146, 1148, 1150, 1152, 1154, 1156, 1158, 1160, 1162, 1164, 1166, 1168, 1170, 1172, 1174, 1176, 1178, 1180, 1182, 1184, 1186, 1188, 1190, 1192, 1194, 1196, 1198, 1200, 1202, 1204, 1206, 1208, 1210, 1212, 1214, 1216, 1218, 1220, 1222, 1224, 1226, 1228, 1230, 1232, 1234, 1236, 1238, 1240, 1242, 1244, 1246, 1248, 1250, 1252, 1254, 1256, 1258, 1260, 1262, 1264, 1266, 1268, 1270, 1272, 1274, 1276, 1278, 1280, 1282, 1284, 1286, 1288, 1290, 1292, 1294, 1296, 1298, 1300, 1302, 1304, 1306, 1308, 1310, 1312, 1314, 1316, 1318, 1320, 1322, 1324, 1326, 1328, 1330, 1332, 1334, 1336, 1338, 1340, 1342, 1344, 1346, 1348, 1350, 1352, 1354, 1356, 1358, 1360, 1362, 1364, 1366, 1368, 1370, 1372, 1374, 1376, 1378, 1380, 1382, 1384, 1386, 1388, 1390, 1392, 1394, 1396, 1398, 1400, 1402, 1404, 1406, 1408, 1410, 1412, 1414, 1416, 1418, 1420, 1422, 1424, 1426, 1428, 1430, 1432, 1434, 1436, 1438, 1440, 1442, 1444, 1446, 1448, 1450, 1452, 1454, 1456, 1458, 1460, 1462, 1464, 1466, 1468, 1470, 1472, 1474, 1476, 1478, 1480, 1482, 1484, 1486, 1488, 1490, 1492, 1494, 1496, 1498, 1500, 1502, 1504, 1506, 1508, 1510, 1512, 1514, 1516, 1518, 1520, 1522, 1524, 1526, 1528, 1530, 1532, 1534]
# ntt_prod: [0, 2954, 1556, 2466, 2357, 1231, 2419, 2594, 1758, 3242, 390, 3191, 1660, 2457, 2255, 1056, 2191, 2333, 1484, 2975, 150, 2998, 1534, 2418, 2323, 1251, 2533, 2842, 2180, 549, 1280, 1046, 3178, 1020, 1232, 487, 2116, 2792, 2517, 1293, 2451, 2664, 1934, 263, 982, 764, 2940, 854, 1166, 549, 2334, 3194, 3131, 2147, 244, 753, 347, 2357, 127, 317, 2929, 1307, 2111, 2014, 1018, 2454, 2995, 2643, 1400, 2597, 2907, 2332, 874, 1864, 1975, 1209, 2897, 383, 327, 2731, 939, 1611, 1420, 368, 1786, 2347, 2053, 906, 2237, 2719, 2354, 1144, 2420, 2855, 2451, 1210, 2463, 2883, 2472, 1232, 2494, 2931, 2545, 1338, 2641, 3127, 2798, 1656, 3032, 270, 30, 2314, 466, 1146, 1027, 111, 1729, 2554, 2588, 1833, 291, 1293, 1512, 950, 2938, 820, 1256, 919, 3140, 1263, 1948, 1868, 1025, 2750, 387, 596, 50, 2080, 30, 560, 343, 2710, 1005, 1888, 2032, 1439, 111, 1379, 1916, 1724, 805, 2490, 123, 364, 3215, 2020, 110, 816, 811, 97, 2005, 3208, 379, 178, 2607, 1010, 2047, 2391, 2044, 1008, 2614, 206, 444, 1, 2208, 409, 1264, 1446, 957, 3128, 1303, 2142, 2318, 1833, 689, 2217, 3090, 3310, 2879, 1799, 72, 1029, 1343, 1016, 50, 1776, 2867, 3325, 3152, 2350, 921, 2196, 2848, 2879, 2291, 1086, 2595, 162, 447, 123, 2521, 985, 2175, 2764, 2754, 2147, 945, 2479, 93, 447, 214, 2725, 1324, 2671, 110, 301, 3246, 2289, 761, 1993, 2658, 2758, 2295, 1271, 3017, 877, 1511, 1592, 1122, 103, 1866, 3084, 430, 564, 159, 2546, 1069, 2388, 3176, 106, 3167, 2374, 1058, 2550, 194, 650]
# poly_prod: [0, 2954, 1556, 2466, 2357, 1231, 2419, 2594, 1758, 3242, 390, 3191, 1660, 2457, 2255, 1056, 2191, 2333, 1484, 2975, 150, 2998, 1534, 2418, 2323, 1251, 2533, 2842, 2180, 549, 1280, 1046, 3178, 1020, 1232, 487, 2116, 2792, 2517, 1293, 2451, 2664, 1934, 263, 982, 764, 2940, 854, 1166, 549, 2334, 3194, 3131, 2147, 244, 753, 347, 2357, 127, 317, 2929, 1307, 2111, 2014, 1018, 2454, 2995, 2643, 1400, 2597, 2907, 2332, 874, 1864, 1975, 1209, 2897, 383, 327, 2731, 939, 1611, 1420, 368, 1786, 2347, 2053, 906, 2237, 2719, 2354, 1144, 2420, 2855, 2451, 1210, 2463, 2883, 2472, 1232, 2494, 2931, 2545, 1338, 2641, 3127, 2798, 1656, 3032, 270, 30, 2314, 466, 1146, 1027, 111, 1729, 2554, 2588, 1833, 291, 1293, 1512, 950, 2938, 820, 1256, 919, 3140, 1263, 1948, 1868, 1025, 2750, 387, 596, 50, 2080, 30, 560, 343, 2710, 1005, 1888, 2032, 1439, 111, 1379, 1916, 1724, 805, 2490, 123, 364, 3215, 2020, 110, 816, 811, 97, 2005, 3208, 379, 178, 2607, 1010, 2047, 2391, 2044, 1008, 2614, 206, 444, 1, 2208, 409, 1264, 1446, 957, 3128, 1303, 2142, 2318, 1833, 689, 2217, 3090, 3310, 2879, 1799, 72, 1029, 1343, 1016, 50, 1776, 2867, 3325, 3152, 2350, 921, 2196, 2848, 2879, 2291, 1086, 2595, 162, 447, 123, 2521, 985, 2175, 2764, 2754, 2147, 945, 2479, 93, 447, 214, 2725, 1324, 2671, 110, 301, 3246, 2289, 761, 1993, 2658, 2758, 2295, 1271, 3017, 877, 1511, 1592, 1122, 103, 1866, 3084, 430, 564, 159, 2546, 1069, 2388, 3176, 106, 3167, 2374, 1058, 2550, 194, 650]
# ek b'\\({\x85q\x83iaP\xf1\xe7\xa9\xf3\xc4!$\x8b\xa15\xa1p\xe6\x84lZ\xe6\xac\xf7\xd2\x1e\xf2\x05w\x8a\xf3%\xda\xa3\x82l\x16\x0c;\x10:3\xb4\x02\xf6\xfb\xa2\xfa\x95\xc4x\x93\xb2\xeb\xd4\xa8\xael7\x1f\xe29Z\xack@\xe6Fal\x03v\xe2V\xf6C\xba\x9aE\x8c\xf3*#\x9a\x95I\x12*\xb8T\xb7\x04\x136\x80\x14)\xb4d8\x9f\xf5\xf8R\xfd\xd5\xb1E"op\xfam1G\xa0f\xd1R\xdcr6rK\xcfe\xbc6\xe1b\xad\xccIS=b\xb1x\x92\x99,\x1b3\x94\xc2\x9e\xfc\x91Q\xfc|9\xd2\x13\xc1\xbf:\x0f\x081\x0b\xc9\xa1\x81\xc7\xf8\x83\x81\x90a5\xe6\x91\xa4\x04\xa3\xeb\x91\xb8\xda\x92\xa3&\xcc\x9c#\x81]`\x92\x00\xd5\xd1F\x81F`\x8a\xc9&\x83\x9b&\xa6Gjwl\xbe\xc7\xc9\x0b]\xa5jA\xb5\x16\xb1\xbc\x95\x0b\xf8$*\x05\xb7\x18\x11\xac^\xa02\x8e\x87\xc5\x81\xb5\x8f\xe1\xc8\xbe\xcd\xb1<\x15\xa2\x06i\x1c\xb7vp)\xa6\xd74N\xect\xef\xd2Hh\xf0\xb4\xbcc5\xa5\x18Z{v\x80h\x0brS8DE@\xc0\x133?8\xf6\x8f"\xc73\xcd\xbbD\xe5%\xba\xd2\xb4<i%\x86\xa8\xe5#\x98\x88a\x17&\xb7q\xe0K\xa6\xf7\x83q\x80by\xb4V\xab4e\x1f\xab\xb0\xe5\xc8\x94\x8b\x93\x03\x0fp\x9f\x9d\x82n7Q\x85S\xd2\x05\xf0\xa6\x93\x01z\x06\x12\xac\xa0\xecG\xa2s\xe4%\xf4\x0c\xb9C\xc9@!R\x1aP\xf6V\xc5r\x9d\x19\x1c\x19\x91r\xce\\+\xa4\xa6&\xca\x14\xc4\x06\xe1\x87s\x94\xd5bx\xcas\x9d\xcb\x92\xc5\x806\x8b\x99\x00\xa7\x07A%\x80\x9dR\x1b\xc4,$\x93\x80ls\x92:\x82s\x16_k\xc0K\xd6b@#\xd5f\x8a,=~\xb6X\xdc\x94\x7f\x817\x97\xfc*x4\xc9\xad1\xccmzj\x80N\xb8\x8d\x12\x0b%\xf3\x04\x07-6\x08>\n8\xf9\xd0;i\xcb\x91\x0e\x97\x81\xf9\x18LC\xf8x\xc6F|\n\xc8g\x97|\xb9\xd9\xd6_\x9b8\xce\xd3\x11s\xc05<\x8a\xa9^ru\xac\x07\xeb\x96\x8c\xe3\x10\x08\x99Xe\xdcT,bk\x95\x08\xbfy\x91,\xc3|"\xeeV\xb3\x89\x17\x0e\x1a\x08kd\xe1,\xe3\xac\x8e\xb7d\xbaS\xab\x1a\x8e\xb8\x8c\xc7\xb2\x98\xd8i\x01\x8fJ\x9e\xe0\x00\xb0\xa2y[\xe7Xxp\xaa3\xf9\x91G}\x0b\xcbI\x83\x11\xf5\xb0q\x9f\x82\xc7\x0cT\xc0z\x89\x14W\xec\xa8\xba@\x99\xc0)E0\x16\xca\xed\x83\x9d\xe9I\xcbh\xe6e\xa4\xe5\xc4\xa3\\zk\xc0\xc9"\xa25\x17#0K\x80\x8axA\x14\xe2PJ?j\xaetb\xbd\xab\x10}\xaa\xb8p\xfe\xf2\xa2\x15\x97s\xc0\x12n;\xc4\x82\xd1|-\x13\x84S\x88T\xa5F\xd0R\xb1\x17W\xe1T\x92\xc7\x94"\x16\x9c\xb6\xf7\xf0@\xa5\xe0O\x18\x8c\x9e\xaa\xc1\x9c%\xf5\xb5,\x00\n\x92\xf2`\xdc\xf8\xaf(\x12\x89\x8b\xf3\xa0\x98\x97N\xf63\xc4r\xc6\xc9\x8d\xb0:y\x8acO\x86Q\x02\xacY3(\xa1\xf8\x94\x7f\x88sf\xe8dx\xab\x91|\x8bK\x8c2\x15\nxH\x1a\x8a\xf4\xc7\xd1rU\xa7K(4\x9az\x85\xc2\x9b\xf1"\x81\x9a\x8b\xc7U[\xa0-\xe3\x08\xdfQJ51g\xc2\xc4\xb5"\x18#\xd1\x19-\xaf\n\x806\xc0\xbf\xf8\xd0\xb5\x96\x0b\x01>\xc4\x17\xaa$\x0b\x14\x96\x97\x0f\x153\xfb k\x89\xd7\xb7\xc7Vl(\x15\xcdV\xd7\xb7\xc7[\x04U\x08\t\xb5\xb5\x9c`\x16\x86\xd2\x03\\\x0c\xd7\x8d\x93\xfc\xbdf\xa1\x1fcBTq\xb2s\x84\x99emGY~\xba3\x8e\xa7\r/\x86S\x165H\x15y\xcdc\'\xc0\xb5Z\xa2\xe7\xd39\x81\x13(p\xfa\x8b\xf2)\xa2I\x97\x07w\xf5F\x00+G\x84\xc2b\xecv\x19Z\x94e\xc4\x9ai\xa81\x8c\x10\xc5E\xf8G\xc7\xf5\x951\x19{\x86\xe3B\x17\x03s!\xa6\xb4\xcaO\xfb\xa71P\xac\xee@\x03\x0f\xc88\xe7\x1b\x0cM\xa6\x9db\xdcJAGc\xca\x032\x8a\xc0j\xa0f\x8dX\xc7V~k\x07+\xbcXQ\xd2\x95\xb9\xf3\xc6\xd5\njmj\xbcX;)\xee\x17j\x8a\x87?\xc2[0\x98Q\x8b\x92WZ\xc9\x87p!\xc1\xb7\xcfb\x0c\xc9\xe4$w\x0bA\xfe\tl~A\xce(aN\x8f\x86\xb1i\xa1\xb7\x0c\xe3\x18\xd9Z\x0e;3\x0f\x1c\x12\xc6\x97\xd74R\x95M\x95wyU\x12\x1a\xa2c.1\x97\xb2X\xc1\x7fP`\x12\x8e\xd6\xa9f0\x1b@\xa2|W\x10g\xa5X\x84W\x81\x88|\x05+V\x12gn\x84\xa9\x07\xca\\6D\xc9)M\x91?\x8ec\x9d\xec1\xa5c\x1c\xad\xe5\xdd\x08\x1e\x04:\xe5v\xe9H\x97R\x00\xb6J\x83\xa1)\xed'
# dk b'\x04bI\xd8\xa0\t\x12\xca\x13+\xfb\xb6$\xc6$\x8a\x92\x96\x15\xd5D\xfe4&m\x10\n\xae\xc91\xc4\xd7]\xa8\x86\x96 `I\x15\xa1\x1f\x8f\xba)n)\xa7,@\x8b|D@3\xc2j\xdd3\xb6\xf1\xa6g\xe9\xc6\xa1R\xfa\x93\xb3\x95\xb1\xc5\xdb\x04\xa5\x89\x11b\xebA\x92\xfc\x97K\x01\x03/hy\xe3Uq:\xd2mf\xc1\xc6k\xd83\x1cY\n%\xa7t\xfa\x0byO\xc5\x84\x80\x84w^\x0b\x9b\xf4\xd0v\xc3\x88\x01\xdb$\x8e\xbe\x11\xa0\xe3V\x15\x0e\xa6=\x89s,\x06\x84go\x91}\xc6\x05\x13\x08\xe9yZl\xa0\xb5\x87\xb9HrEWu\x84\xc1\x96\x08n\xea\x9c\xd2\xac-\xc6:YdV\x99\x06\x01+7y\xbc\xee\x9a-\xd8\x0cok\x1a\xb9\xd4\xa3\xc6\xcd\x83\xcd\x12\x17\x8cf\x16$^\xec\x8cG\xaa\x92\xc1u\x15\xe9\x9cp\xf1\xc2:\x1e|\x03R\x94\xc1t\xf9M\x97\xdcv\xd8$\x14z\xf9\xaa\x1c\x10\x1f2\xa0_b\xf5(\xf7\x11\x917\xac\x1a\xc3j\x08\x07Ws\xcdP\xa0R\x08$\n\xb7\xae\xe0\xa42\x16\x05Q\x196,5i_\xa6l:\x8e\x1b!Q\xcc\xab\xba\xa9\x80.\x85\x08\x8c4f\x8c\x8b \xd2\xcc\x02\xd7\xd4\x8b\xf4:P\x82\x86\x9fn\x16R)\x17\xa0\x1b\xc5A\xdb\xe4%\x03(m\x0ce\xcb5\xc2\x88&\xa3\xb9\x0e\x9a\x95J\x97\x81\xd6\xc0x\xd6f\xb2\x03\x10\x806l\x16~\x88\xa1)\x0c\xd0\xd6\x9c\x1c6\xc7e\t4X@+%\x0b\xf7\xa2C1\x84\xba\xb4}6\xab\x00U4\x14\xf6\xf9\x8eD\xb5*\xb4R\xc6\xda\xdbk\xb0\xd4$\xa3\xbc\x03\xea\xf3\xc5\x99\xb98\x90B\x18\x80v\x8b\xbe\xa7\x02\x7f\x84b\xfc|I\x18c\xc9\x0b\xc6\x80\n\xaa\n%X\x05-C2\xdb\xaa\xa2\x98\n{\x9b\'\xa4\xef\x19/Nql\xc03.\xa8E+\xf1\xa3\x19\xb5,\x10_\x93\x99\x9c&\xb8\x14i\x07\x8b\xf3\xc0DY\x19N\xcc\xac\xf7\x8cw\x89\xb9\x94Q\tsZ4\xb6\x97i8\xce\x05Bz59\x00\xa1{\x8a\x11lgG\x9c\x03{_s\x00\xaav\xf8\xc6\x86i\xbb\xe3\x90\x0c\xd2\xda\x96\x83\xd3\xb4I\x03{J3g\xe3Z\nC\xda93x\xb9\x88\x8c\xc3\xa1\xe5\xa0\xdf\xe9\x81\x91\x15\xc9\xaf\xeb_\xe4\x9c\x1b\xb1\xda=\xf7\xc0\x0fFy\tb\x9c\x86g\xc5\x9b\xbe\x8b#\x9f\xe4\x81\xf8\x1c.\xf82\x12\xf4:\x8d\xd6\x81\x9e\xc94\x00sk\x15\x01 \x07>r\x9cp\xd3\x949h\x059\xf5d\x04\xa40\x1f\xb6\x94H\xa0u\x91\x88\x93\xe3K9\x80V\x9cM\xa2.\xa2\'\xc2\x85\xd9\xaa\x88\x0c6\xb3\xf8\xb4\x81\x17\x1f0\xba\x1f\xf6\x00\x86)\xa8\xb9\xed5\xb6L\xfb(\xb4\x94T\x0f\x9c\x03h\xb9\xc7\t\xb5\x0b\xb4\xab\x05\xa7a\x87\xbc\xaa]\xeb`\x14\xa5H\x8f\x8bIlcVJ\xbd\xbb.\xa1\x9a\xbf\xdbx/,\xf1\x84\xbclw\\VH\xe9\xa9\x8d\xcf"\xac\x9aq\x85\xdc\xdc\x1b\xa0\x87\'\xb1\xaa1*\xf0\xc4R\x199M\xbc[\xc0\x0cH\xd8\\VJ\x82\\\xe3\x99s\x14\xf7\x15\xeb)-\xc6\x9c \xbdp3\x9f\x83;\x16\x84\x8b\x05w\xcb\nV\x01\xe5\xa6\xc7\xbbY\x99\x08\xe6_\x0b\xa0\x16\\b\x9e3@:.$\x8c\x9a\x01G\xe9\xc2Co7S\xe55\xb79\xb2I\xfa\xf2\xad8\xda\\\xde\xa42\xe5\xa9GAS\r/\x98\x17\xb4\xfb\xc82[\x1e\xf0F\x00\x9dB\xbf\xe8\xb4R\xc8:\x9a\r\xf0:\xb0\xc8o\xe4V\x95OSb\xba\x87D\xd3t\xb8\xb4[m\xdbZ{/\x06\x0f\xb2\xb70\xe1\x96\xba\x8c\xf1E\x87\x1cz\x90Dz\xb2(<\x1c:\\\x9fDl\xd4\xa8\xa4j\xd0\xa7\x97\x880\x0b\xd2\xbf)\x85F.2\xba4\x96t\xa4\xb6\xb2Z\x85\xc5\rRA\x1a\'\xac\xaf\x12\xbdbFw2\x11\xc9\x9b\xd0pt\xc8&j,\xb4\xa9\x1a\x90{\xccx+\xb9\x1b\xef\x89\x9f70n\xb4\x86\xbb\xc7\x83?\x1a\x81\xc6@$t2`\x85a\x94.\x08l\x17\xa3 ~\xf2\xd1$\xdcG\xcdN\n\x85^k #\xa2\xc5.z\x99\xf6\xe2%6i\x08\xb4\x93wqb\xca\x86\x17\x82\xc6\xbc\xb9\xadSPU;]\xe5\xd3\xca=\xe7}\xee\xf7Q\x07t\xcf\xf1\x10K\x8b\x0b\xc5\x1d\x14\xbcz,$\x0c\xeblh*K\x9d\x08{t3\x00o\xd8\xa8\xfc\x17Z\x1b\xf9sF<\xca\xd0\x89\xb7\xa5\x03\x84\x99U$\x94\xa8\x9fy\x02\t\xc4[\xb9d\x93\x9d\xed\xd8\'\x979\x03\xbdL\xa8s\x93x\rg\x0cwI1U\xc4\xac\x19\xb3$\xdd\xd9B\xac\x13\x1f\xde\x98\x92\x8a\xf5@'
# ct: b'\xeb\x8d[T0\xb9\x1cQl\xafK\xc2\xe7pq\x00\x06\x94i\x80e\x06\xd0\x8b$\x04\x9a,l\xd5\xf2\x85\xf0\'\xb6,\xdf\x9f5B4\xe29\xe8}\xd2\x0c\xc8\xf4p3\x1b>\x17+b.\\+\xcd7\xab\xf08\x9b\xc9\xf4jjL~\xf6*\x86\xcdx\x15\x83\x83==\xe1\xbf\xca\xc6i\x8d\x97P\xd8\xe8\x10\xe7\x0f\xc4{GB\x8a\xdeI\x95\xd5\x97\xc6\xf4\x82X\x8b\x0b:\xcbAt\xed\xfa\xfdG\xb3\x9e\xef\xbc\xb7f\x19\xb0g\x08\x1b\xf1&jvE\xab\x1etb\xc5\x0f}\x02\xac\xdfP\x88\xef\x8a\xfa|#\x85s\xcc\xc1\xa1\xaa"R\xc1\x0f\xe4=\x02\xa51\x06p\xbb\xb4?\xea\xe6\x11\xb5\xcc\n\x04\x8e\x87e\x80\xc7c\x84\x8aQ\x04~\x1d\xde\xd3\x84\xe4\xc5J\xa7!\x87\x0c\xf1\x99\xcd\xda\xd1\x88\xe7]&\x81\xa5AC\xfd\xf27[{\xc9\x12\x8a*\xf3\xf9\x92\x88\x1bv?\x8b\xdd\xd8;\n\x10\xf4\xe3\x14R\xe3\xbb\xb2A\xe5\xe1zA\xde\xa6\xb9j!a\x87m\xa4\xc1\xc8n\x81l\xa5\xf96K\xde1\xf65\xc7\xb6\xa6C\x12\xff\x9d&BHE"\xbe5s\xce\xa3Y\x05\x88\x13\xe3\xaf=\xbd\x84\x84\xcf\xbf\xe0\xa3L\x18O\xc8\xc7i\xb1- \x0bUG\x9bJ\xca\xa0I1C\xdb\x06\xd6\xe5{c\xc5*ns\x0b\x7f\x96\x9c\xc1\x8a\xd3\x8e\x9d\xb2\x9f\xb1+6\xbb\x1b\x96\x95\xaa\x041\x95>aL.E\x8a\xcb3\xeb:]\x1a\xae=\xd8W\x9cp\xaf\xd0\xb8\xab@O\xb1\x87\xb4\x84\xedJ\xfadB\x14\xc41[\xffKn\x15?\xd1GR\xde*\x13f\xd7\xd9Y\xcdO\x97H\xa3@?.\xa6\x1aY&\x06H\xaa\xa1\xd1\x8c\xd8\xcbR0\xd5\xf5QF\x0c\xaf\x8d\xef\xe65,g\xc6\x11n\x85u\x0e\xe7IN\xad\x86\xa7\x8b\new\xad\x8a\xe3\x9e\xcd\xfe\xfc\xb0\xb2\xdf\xac\xa2]\tp)\x05I\x89\x8a\xd6\x8c\x8d\x18/b\xbf\x14\x88\xdez\xaf\xd6\xd0X\xa3\xd2\x03\xdb\x8e\x19\xbeoX\xeb~\xdb\x1asA\xde\x11\xe9\xf4^o\xcd\x84%\xdb\xd8|\xc0&\x82\xe6\x80e\x9d\xd3\xbc\x12w\x03\x19\x19<\xf5\x04\xbf5\xcc\xec\xe72\x0e\xb9\x07\x7f\xfd\x9c&\xa3\xf3N\xb3Q\x1f\xd1Z\xdb\x922\xb5k\xb4\x0b\x83R \xffjUylt(\xdbF\x19B,\xbd\\\xf16y\xea\x12\xa8c\x07L\x9d\xfb\x9d\xbf\xd1\xdb\x13\x91\xb0V\x13\xe9\x81Ng\xaf\xb5\xce\xcc\x0e#Y\xdc \xc6\xc4\xda\x8aI8\xc0\xae\xea\xd8\xfcV\xeceD<I\xb1Z\x0f\x9b\xda\x12N\xa0sMQ\x97c\xe1g\x82\x13{\xe0WX\xeaw\xd2cy\x05\x8d\x1dn\x9e\x97B\x7f\xfe\x8c\xa9\xb9\xfc\x87\x8b\x81k\x87<\xfe\x9a>\xcf\xf08.;\x8d\x80{\xb4\xac\x877d\xbc~\xbcm\xcd\xba\x00$\xcb\x9fH\x92\xb2\x14\xb1&\x9e\x90\xd0\xa0\x90\x0b\t\x8a\xcf\x0f\x84\xfa\xd9\xf9\xc4(\x19\xbc\xed\x0e\xea2\xeb\x83\xb2\xdez\xe7\x02\xe1\x0b9W\n\xbe\x1c8\xc8\r\xe7\xa6y\x14z\xca>&\xca\xf0\x03zB\xd5\xdb\x16\xc9\x8e\xafW>\x04YU\xf1\x17\xbe\x1f\xf5\xe3\x82c\x8c\xb5d\x98\xdd\xea\xa8\xe0\xc391\x82\xd9vHY\xd8\x91\xef\xd2\x11\xf41\xa7\r@q\'q\xf0\xee\xc0\x9fS.\x08+\x91K\xf1\x03\xa3_\x9bmb\xd0a\xed\x93\x8b\xf5\x1093\x12\xc3\xbe\xab&\xb1\xed\x1c\xd1\x85jFkP\x07{f\xeb\xb1z\xd8]!N\xaf#\xe3s\xce\xb8g\x1f{h\x12\x8c\t\xfb\xec\x9d\xc7%\x90\xde\xe6XW\xfe9n\x7fY\x0f\xeb\xc4\xc8\n\xf1\xcbs\x06\t\x07\xa5\xf4\xd3\xe2\xffw\xea\xbef;+\x85\xd5 7\xa9lI\xf5\xfb=\x8c\x9e\xfa\x07Sg@2\xc6@H\x9e\xc52\xb24\x0fH\xe4cu\xf0\xb1\xae\x15\x85\x80%\xecs\x83m\xb0\xcd)G,{\xd77\xce\xc0\\\xe6\xe2\x1e\x0e!\xdf\x1cw\xb5J)7\xc8\xbd\xf2\x8e1n\xbc\x8d\xaam\xd4\xaf\x85\xb3\x04\x04v\t\xa3\xf6\x02\xce\xc1\xf0\x1a\x9f\xaa\xd0\xb8\x9f!\xffW\x0b|hF\x1c<\x9aC\x82\xdc\xa9s\xf7;\xe8:\x9c\x12\xc0k\x12\xd4+V!\xf4\x97\xa6\'\xc8\n\x13\x81\x8b\xa8\x03;\xa7\xab\xc3\xe81=\xf5q\xdd\x110\x81Z\xe9\x15d.\xe7\xc9\x85\xd3\x9b\x0c\x9a\x98\xd5\x8a\xca\xaa\xe6\xdcB\xc4O\xad?\xa1\x84\x196\xf7\xa3iG\xc3\xfc\xdc\x06"'
# c1 b'\xeb\x8d[T0\xb9\x1cQl\xafK\xc2\xe7pq\x00\x06\x94i\x80e\x06\xd0\x8b$\x04\x9a,l\xd5\xf2\x85\xf0\'\xb6,\xdf\x9f5B4\xe29\xe8}\xd2\x0c\xc8\xf4p3\x1b>\x17+b.\\+\xcd7\xab\xf08\x9b\xc9\xf4jjL~\xf6*\x86\xcdx\x15\x83\x83==\xe1\xbf\xca\xc6i\x8d\x97P\xd8\xe8\x10\xe7\x0f\xc4{GB\x8a\xdeI\x95\xd5\x97\xc6\xf4\x82X\x8b\x0b:\xcbAt\xed\xfa\xfdG\xb3\x9e\xef\xbc\xb7f\x19\xb0g\x08\x1b\xf1&jvE\xab\x1etb\xc5\x0f}\x02\xac\xdfP\x88\xef\x8a\xfa|#\x85s\xcc\xc1\xa1\xaa"R\xc1\x0f\xe4=\x02\xa51\x06p\xbb\xb4?\xea\xe6\x11\xb5\xcc\n\x04\x8e\x87e\x80\xc7c\x84\x8aQ\x04~\x1d\xde\xd3\x84\xe4\xc5J\xa7!\x87\x0c\xf1\x99\xcd\xda\xd1\x88\xe7]&\x81\xa5AC\xfd\xf27[{\xc9\x12\x8a*\xf3\xf9\x92\x88\x1bv?\x8b\xdd\xd8;\n\x10\xf4\xe3\x14R\xe3\xbb\xb2A\xe5\xe1zA\xde\xa6\xb9j!a\x87m\xa4\xc1\xc8n\x81l\xa5\xf96K\xde1\xf65\xc7\xb6\xa6C\x12\xff\x9d&BHE"\xbe5s\xce\xa3Y\x05\x88\x13\xe3\xaf=\xbd\x84\x84\xcf\xbf\xe0\xa3L\x18O\xc8\xc7i\xb1- \x0bUG\x9bJ\xca\xa0I1C\xdb\x06\xd6\xe5{c\xc5*ns\x0b\x7f\x96\x9c\xc1\x8a\xd3\x8e\x9d\xb2\x9f\xb1+6\xbb\x1b\x96\x95\xaa\x041\x95>aL.E\x8a\xcb3\xeb:]\x1a\xae=\xd8W\x9cp\xaf\xd0\xb8\xab@O\xb1\x87\xb4\x84\xedJ\xfadB\x14\xc41[\xffKn\x15?\xd1GR\xde*\x13f\xd7\xd9Y\xcdO\x97H\xa3@?.\xa6\x1aY&\x06H\xaa\xa1\xd1\x8c\xd8\xcbR0\xd5\xf5QF\x0c\xaf\x8d\xef\xe65,g\xc6\x11n\x85u\x0e\xe7IN\xad\x86\xa7\x8b\new\xad\x8a\xe3\x9e\xcd\xfe\xfc\xb0\xb2\xdf\xac\xa2]\tp)\x05I\x89\x8a\xd6\x8c\x8d\x18/b\xbf\x14\x88\xdez\xaf\xd6\xd0X\xa3\xd2\x03\xdb\x8e\x19\xbeoX\xeb~\xdb\x1asA\xde\x11\xe9\xf4^o\xcd\x84%\xdb\xd8|\xc0&\x82\xe6\x80e\x9d\xd3\xbc\x12w\x03\x19\x19<\xf5\x04\xbf5\xcc\xec\xe72\x0e\xb9\x07\x7f\xfd\x9c&\xa3\xf3N\xb3Q\x1f\xd1Z\xdb\x922\xb5k\xb4\x0b\x83R \xffjUylt(\xdbF\x19B,\xbd\\\xf16y\xea\x12\xa8c\x07L\x9d\xfb\x9d\xbf\xd1\xdb\x13\x91\xb0V\x13\xe9\x81Ng\xaf\xb5\xce\xcc\x0e#Y\xdc \xc6\xc4\xda\x8aI8\xc0\xae\xea\xd8\xfcV\xeceD<I\xb1Z\x0f\x9b\xda\x12N\xa0sMQ\x97c\xe1g\x82\x13{\xe0WX\xeaw\xd2cy\x05\x8d\x1dn\x9e\x97B\x7f\xfe\x8c\xa9\xb9\xfc\x87\x8b\x81k\x87<\xfe\x9a>\xcf\xf08.;\x8d\x80{\xb4\xac\x877d\xbc~\xbcm\xcd\xba\x00$\xcb\x9fH\x92\xb2\x14\xb1&\x9e\x90\xd0\xa0\x90\x0b\t\x8a\xcf\x0f\x84\xfa\xd9\xf9\xc4(\x19\xbc\xed\x0e\xea2\xeb\x83\xb2\xdez\xe7\x02\xe1\x0b9W\n\xbe\x1c8\xc8\r\xe7\xa6y\x14z\xca>&\xca\xf0\x03zB\xd5\xdb\x16\xc9\x8e\xafW>\x04YU\xf1\x17\xbe\x1f\xf5\xe3\x82c\x8c\xb5d\x98\xdd\xea\xa8\xe0\xc391\x82\xd9vHY\xd8\x91\xef\xd2\x11\xf41\xa7\r@q\'q\xf0\xee\xc0\x9fS.\x08+\x91K\xf1\x03\xa3_\x9bmb\xd0a\xed\x93\x8b\xf5\x1093\x12\xc3\xbe\xab&\xb1\xed\x1c\xd1\x85jFkP\x07{f\xeb\xb1z\xd8]!N\xaf#\xe3s\xce\xb8g\x1f{h\x12\x8c\t\xfb\xec\x9d\xc7%\x90\xde\xe6XW\xfe9n\x7fY\x0f\xeb\xc4\xc8\n\xf1\xcbs\x06\t\x07\xa5\xf4\xd3\xe2\xffw\xea\xbef;+\x85\xd5 7\xa9lI\xf5\xfb=\x8c\x9e\xfa\x07Sg@2\xc6@H\x9e\xc52\xb24\x0fH\xe4cu\xf0\xb1\xae\x15\x85\x80%\xecs\x83m\xb0\xcd)G,{\xd77\xce\xc0\\\xe6\xe2\x1e'
# c2 b'\x0e!\xdf\x1cw\xb5J)7\xc8\xbd\xf2\x8e1n\xbc\x8d\xaam\xd4\xaf\x85\xb3\x04\x04v\t\xa3\xf6\x02\xce\xc1\xf0\x1a\x9f\xaa\xd0\xb8\x9f!\xffW\x0b|hF\x1c<\x9aC\x82\xdc\xa9s\xf7;\xe8:\x9c\x12\xc0k\x12\xd4+V!\xf4\x97\xa6\'\xc8\n\x13\x81\x8b\xa8\x03;\xa7\xab\xc3\xe81=\xf5q\xdd\x110\x81Z\xe9\x15d.\xe7\xc9\x85\xd3\x9b\x0c\x9a\x98\xd5\x8a\xca\xaa\xe6\xdcB\xc4O\xad?\xa1\x84\x196\xf7\xa3iG\xc3\xfc\xdc\x06"'
# pt: b'This is a demonstration message.'
# pt (hex): 5468697320697320612064656d6f6e7374726174696f6e206d6573736167652e
# msg (hex): 5468697320697320612064656d6f6e7374726174696f6e206d6573736167652e
# encapsulated: acf1c14f63ab6f855dd11fa33660b6bc96f9c578d2976f84aa81fd6121e9d20c
# c1 b'\x94\xa6\xe3E\x8b\xea\xdd\xa6\x7fp\xf9\xe0\xf5\xdf\x88\x02\xd7\xd7\x9f6\xaf\x12 \xdb7\xda\xb5\xeem\xf1\x96\xf8a\xdeFI\xbas \x10\n\x9c[\xa5\x07\x05\xa3\x7f"\x82\x84\x1c\x8f\xc1\xa8/hWs\x84\xc2\xfds\x85\xed\xc5\xcf\xf0\x0c(\x19\x0b\xaa\xcfH\x10\xe4\xaf\x91\x96\x04A\xa4\xc4\xac\x8f\x9b,\x01\x9f9\xcc\x18\xe9@_\x03\x0b\xb2G\x16\x04tq\xb0\xdf\xa4\x1cjY\xdc\x05\xfe\x83=8_.\x8fog\x8f\x9c\xa9\xeeA>\xe7\xbfb\xa7\x15\x0f\xbd\xbcMP\x1d\xc4\xc0\xf7\x07\xa90u\t\xe0\x18\xa8\xf4\x16\x97\xcbM\xd4\x80\xd6\xf1\x07i\xb7z\xebt\xae\'\x076\x8b\x15\xd4\xa1[)\x0f\x0f\x07S\xfd\'x%\xed\x93\xebLQKa\xb4\x95\xc5=\xa6e:4\xb3\xee\xf9S#\xa1\xd60Lv\x1d\xcc\x17\xffRj\xdb\x00\xb0\xa9\xfc\x87(\x18\xef\xde\x17\xe1\x06\x9fm\xb82\x83\x8f\x942\xdc~\x1f\xce\x99C.tR\xe8=\x8b\xb4y9\x8d\x92\xec|\x91\xa2\xdf%\xb4x^\xdc\xdb\x82F\x81\xd2*\xe0\xea\xa7\xb7\xa6\x8a\x93\xe5=\x16N\xa2\xb9\x19\xcco\xfe\x82QQ\xe5\x0b\xeb\xdat\xf8\x02*\x1c[\x1d|\x13T\xc6u^\x97\x01\xcaJT\xf9*]9\xcdB\xda\x8d\xc8z\xb5\x99\x8b01\xe5M\x1a\xbev\xe9Aj\x8b\x9e\xf1g\x1aJ\xf9l\xd8\xb0\xf5\x81G\x88\x95\x12\x96\xaf\xeaq\xb9\xceEE\xbe\xa1c\x11[\xd7\xee[\xbb\xae7],\x9b\xf4k0r\xe8P\x0c\xedR\xd2!=\xd3\xbb\xea\x03\x88P\x87\xac(\xf8P\x04v\\d\x8f\xde\xcd\x12\xec\xd05\xc9\x82\xcc\xbe\x8a\xa4m("B\xf9\xb2\x833`M!T\xd8I1:\xff\x1b\xbd\x14\x1aO\xd8\x95\x1e\xb6\x96\x9f\xfa\xe9%\x054\xfd\xfc/\xacvj\xad\r\x92WA\xedF\x8a\xe4\xbc\xc0\xa2!\n\xd9\n:\xfe\xf3\x8e\xd2\xdd\xd0\xa0$\xcd\xe1g\xb20r\xcdw\xef\x8d\xfe\x98m}_\x99n\x1c\xd5\x89B\xdd\x82\xa8\xc6\xc6}\xdc-\xc6=\x89\xd4l\xa2><\xb2\xec\x9com\x1b\x98\x0b\xbd8@z\xa6OLa=*7\x91+\xc0\xe5\x9b\x9e{=\x00\x07\'\x8f\xbe\xeaH\xad\xae\xc8\x9fK\x93\x84\x8a\x81\x02\xb9W\'\x02\xf7Q\xad\xbbul\xee\x15\t\x12\x1a\xceM\xfcc\x97\xc5X\x91\xcf\xfa\xd3\x93\x99\xae\x03+\xe7p\xee\xee\xcd\xa8rO5u\x1a\xe0D\xcd$c\xa6r\xdaq\xeb[\x92,w#\x0b\x077u[\x05\xd2\x19P&\x17\xb7TM\x1f\xdb\x93A\x85E\xfd\xc83\xce\xf7{\'\x8d\xe3\x8a\n\x85\x1dS\r\xa9\xe6\xc5\xa6\xc4\xd4\x88\xeb4\xf0i\xc4\xfc\xe4Z\xf71y\xe1\xbd7S@\xea\xa0\xed!\xcf\x8c\x0f\x1f{\x15\xb4W\xe2\x9ex\x8do\xc4\xbb\xf5Ah\x92\xb7\xe68\xac\x94M\xcb\xea\t\xa6HP \xd7\xcf\x1e\xf7\x7f\x88pfV\xc4<\xb3Ys\x93p\xfcxV\xde\x17\x9d\xf1c\x0b\xca\xdfif\xb4\x94\xd1\x99\xaa\x83\x8a\xa7p\xc4_\xde\xea\xb0\x973\xd1\xee\xa7]\xc4\x0ef\x8dsJ\x97\xce(\x0f8o\x10\xef\xbb`\x02\xf9^\x10Gu\x1b\xc1\xec\xd4-\\\xcf\xcd\xc9\xf5R\x88\x1e\xcd\x164\x90\x94p\xaf\xa5\xf1^)\xa4-\x8do\xea\xceq\xb7\x85U\x9d\xe6\xd6Y\x10B\x1fLK\xfd)\x9b\xf6}\x87D\xaa\xcc\x18y8\xef\x8b\xd1\x1e\x14\xca\x07\xc9\xbc\x07\x11\xe0\xbe\x8d\x1d\x84\xd6Z\xbd#(~S\x90\xef\xcd\x8d\xbaM\t\x0f\x1b\x1eY&\xaa\xecI\x8a\x0c\xb4`\xc6\x08\xa0\xa6#w\x91d\xdb\xf4\xc7\x80$\xa3J\xe3\xcbZ\xbb\xb6\x9d\xc4\xaa\xb0\x81\xc1\xce8]-\xea/\xc0\x02\x07&\x93\x9e\xfc\xac\x03\xecm\xb1\xb4\x1a\x9d\xcf1K\x1c\xf2e\x9c\xc1E\xb0\x00.\x1dr\x8dC\xa9\xa2\x1b\xe5\x0b\xad\x8f)\xc6\xeb>>\x99\xa1\xee&\xbdL{\xed\xf9\xd8\xcf'
# c2 b'b\xe1\x85\x94\x90\xbf\t5\xec\x9f\xca\xea\xdbg\xb6\xfb\xf2(~\xd8\x80\xf2\xc8\xf8zv\x89\xe0\xaa\x03\xfd\xe2\xa0\xaa\xe9\x16\xea\xaf\xed\x0e\xcb\x87\xe1$\xee\x9a\xff\x81\x1dd%"\xee\xef\xe1\xbf\x9e\xda\xc8\xed\xbb\xce\xb6\x81\xc4\xb6#S\xe6\xad\x80\x9cNN(\xfa\x15\xcfR\xcffw\x01X;\xfe\xab{s\x0c\xdd\x17vv\xc1Z\xe1\xdc\xa0Y\xae}W5M\xa9+\xd9\xee\x0b\xa0\xfa\xa2\x96\xda\xd6\xc5\x85\x9b\x16TSGgo\xaa\x11\x90'
# decapsulated: acf1c14f63ab6f855dd11fa33660b6bc96f9c578d2976f84aa81fd6121e9d20c
